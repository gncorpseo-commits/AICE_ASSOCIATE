# %% [markdown]
# # 데이터프레임 집중 트레이닝 - 데이터셋 로더
#
# 이 노트북은 `practice/datasets/`에 있는 CSV를 빠르게 불러오기 위한 시작 템플릿입니다.
#
# - 필요할 때 `DATASET_PATH`만 바꿔서 사용하세요.
# - 로컬에서 바로 실행 가능한 경로로 구성되어 있습니다.

# %%
import pandas as pd

# 사용할 데이터셋 경로를 선택하세요
DATASET_PATH = "../practice/datasets/iris.csv"

df = pd.read_csv(DATASET_PATH)
df.head()

# %%
# 다른 예시 경로
# DATASET_PATH = "../practice/datasets/titanic.csv"
# DATASET_PATH = "../practice/datasets/tips.csv"
# DATASET_PATH = "../practice/datasets/winequality-red.csv"
